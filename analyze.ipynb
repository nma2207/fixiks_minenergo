# %%
import pandas as pd
import datetime

# %%
accident_weather_filename = "Аварии_погода_САЦ_2020.xls"
accident_weather = pd.read_excel(accident_weather_filename)

# %%
accident_causes_filename = "Аварии_Причины_САЦ_2020.xls"
accident_causes = pd.read_excel(accident_causes_filename)

# %%
accident_weather
# Out:
#           Дата                  Субъект РФ                       Причина  \
# 0   2020-05-25         2020-05-26 00:00:00  Падение деревьев (природные)
# 1   2020-04-20              Алтайский край                        Пожары
# 2   2020-09-15              Алтайский край  Падение деревьев (природные)
# 3   2020-04-22   Алтайский край, Казахстан                        Пожары
# 4   2020-04-08            Амурская область                        Пожары
# ..         ...                         ...                           ...
# 221 2020-06-03        Чеченская Республика              Погодные явления
# 222 2020-06-24        Чеченская Республика              Погодные явления
# 223 2020-07-25        Чеченская Республика                        Пожары
# 224 2020-07-23  Чукотский автономный округ                        Пожары
# 225 2020-07-09         Ярославская область              Погодные явления
#
#                                            Подробности  \
# 0    Причиной падения дерева являются природные при...
# 1                                        низовой пожар
# 2    Причиной падения дерева являются природные при...
# 3                                        низовой пожар
# 4                                        низовой пожар
# ..                                                 ...
# 221  3 июня с 21-30 до 02-00 4 июня из-за неблагопр...
# 222  24 июня с 20-13 до 21-21 из-за неблагоприятных...
# 223                                      низовой пожар
# 224                                лесотундровый пожар
# 225  9 июля с 07-00 до 16-40 из-за неблагоприятных ...
#
#                        Тип объекта
# 0                              ЛЭП
# 1                              ЛЭП
# 2                              ЛЭП
# 3                              ЛЭП
# 4                              ЛЭП
# ..                             ...
# 221  Повреждения нескольких ЛЭП\ПС
# 222  Повреждения нескольких ЛЭП\ПС
# 223                            ЛЭП
# 224                        ПС, ЛЭП
# 225  Повреждения нескольких ЛЭП\ПС
#
# [226 rows x 5 columns]

# %%
accident_weather
# Out:
#           Дата                  Субъект РФ                       Причина  \
# 0   2020-05-25         2020-05-26 00:00:00  Падение деревьев (природные)
# 1   2020-04-20              Алтайский край                        Пожары
# 2   2020-09-15              Алтайский край  Падение деревьев (природные)
# 3   2020-04-22   Алтайский край, Казахстан                        Пожары
# 4   2020-04-08            Амурская область                        Пожары
# ..         ...                         ...                           ...
# 221 2020-06-03        Чеченская Республика              Погодные явления
# 222 2020-06-24        Чеченская Республика              Погодные явления
# 223 2020-07-25        Чеченская Республика                        Пожары
# 224 2020-07-23  Чукотский автономный округ                        Пожары
# 225 2020-07-09         Ярославская область              Погодные явления
#
#                                            Подробности  \
# 0    Причиной падения дерева являются природные при...
# 1                                        низовой пожар
# 2    Причиной падения дерева являются природные при...
# 3                                        низовой пожар
# 4                                        низовой пожар
# ..                                                 ...
# 221  3 июня с 21-30 до 02-00 4 июня из-за неблагопр...
# 222  24 июня с 20-13 до 21-21 из-за неблагоприятных...
# 223                                      низовой пожар
# 224                                лесотундровый пожар
# 225  9 июля с 07-00 до 16-40 из-за неблагоприятных ...
#
#                        Тип объекта
# 0                              ЛЭП
# 1                              ЛЭП
# 2                              ЛЭП
# 3                              ЛЭП
# 4                              ЛЭП
# ..                             ...
# 221  Повреждения нескольких ЛЭП\ПС
# 222  Повреждения нескольких ЛЭП\ПС
# 223                            ЛЭП
# 224                        ПС, ЛЭП
# 225  Повреждения нескольких ЛЭП\ПС
#
# [226 rows x 5 columns]

# %%
print(accident_causes.dtypes)
print(accident_weather.dtypes)
# Out:
# Дата (местное время)    datetime64[ns]
# Субъект РФ2                     object
# Причина                         object
# dtype: object
# Дата           datetime64[ns]
# Субъект РФ             object
# Причина                object
# Подробности            object
# Тип объекта            object
# dtype: object

# %%
test_subject = "Алтайский край"
test_date = datetime.datetime(2020, 4, 20, 0, 0, 0)
test_date2 = datetime.datetime(2020, 4, 20, 23, 59, 59)

# %%
accident_weather[accident_weather['Субъект РФ'] == test_subject]
# Out:
#         Дата      Субъект РФ                       Причина  \
# 1 2020-04-20  Алтайский край                        Пожары
# 2 2020-09-15  Алтайский край  Падение деревьев (природные)
#
#                                          Подробности Тип объекта
# 1                                      низовой пожар         ЛЭП
# 2  Причиной падения дерева являются природные при...         ЛЭП

# %%
cond_subject = accident_causes['Субъект РФ2'] == test_subject
cond_date = ( accident_causes['Дата (местное время)'] > test_date) &( accident_causes['Дата (местное время)'] < test_date2)
accident_causes.loc[ cond_date & cond_subject]
# Out:
#      Дата (местное время)     Субъект РФ2  \
# 129   2020-04-20 15:57:00  Алтайский край
# 132   2020-04-20 19:49:00  Алтайский край
# 3942  2020-04-20 11:24:00  Алтайский край
# 3994  2020-04-20 06:16:00  Алтайский край
#
#                                                 Причина
# 129                                    Природные пожары
# 132   Прочие воздействия неблагоприятных природных я...
# 3942                        Воздействие животных и птиц
# 3994                        Воздействие животных и птиц

# %%
fire_filename = "Пожары_2020.xls"
fire = pd.read_excel(fire_filename)
fire.columns
# Out:
# Index(['fid', 'LATITUDE', 'LONGITUDE', 'BRIGHTNESS', 'SCAN', 'TRACK',
#        'ACQ_DATE', 'ACQ_TIME', 'SATELLITE', 'CONFIDENCE', 'VERSION',
#        'BRIGHT_T31', 'FRP', 'Федеральны', 'Район', 'Субъект'],
#       dtype='object')

# %%
#t = fire['ACQ_DATE'][0]
t = fire['ACQ_DATE'].apply(lambda x: x.date())

# %%
cond_subject = fire['Субъект'] == test_subject
cond_date = ((t>datetime.date(2020, 6, 25)) & (t <= datetime.date(2020, 6, 30)))


#dates = datetime.datetime.strptime(fire['ACQ_DATE'], '%d.%m.%y')

# %%
fire[cond_subject & cond_date]
# Out:
#       fid  LATITUDE  LONGITUDE  BRIGHTNESS  SCAN  TRACK   ACQ_DATE  ACQ_TIME  \
# 0    1724    51.425     81.353       336.3   1.0    1.0 2020-06-30  07:30:00
# 1    1725    51.423     81.338       325.0   1.0    1.0 2020-06-30  07:30:00
# 2    3156    52.818     84.860       317.9   1.2    1.1 2020-06-27  05:15:00
# 3    3157    52.680     84.896       314.7   1.2    1.1 2020-06-27  05:15:00
# 4    4584    53.427     85.636       314.8   1.0    1.0 2020-06-27  07:00:00
# 6   12578    53.486     82.905       363.8   1.4    1.2 2020-06-29  06:50:00
# 7   12579    53.489     82.896       343.2   1.4    1.2 2020-06-29  06:50:00
# 8   13022    51.197     79.983       353.4   3.4    1.7 2020-06-29  08:25:00
# 9   13023    51.196     79.934       360.6   3.4    1.7 2020-06-29  08:25:00
# 10  13024    51.213     79.982       331.7   3.4    1.7 2020-06-29  08:25:00
# 11  13025    51.211     79.933       320.5   3.4    1.7 2020-06-29  08:25:00
# 12  13026    51.228     79.982       350.3   3.4    1.7 2020-06-29  08:25:00
# 13  13027    51.244     79.981       331.5   3.4    1.7 2020-06-29  08:25:00
# 14  13028    51.206     79.979       350.3   3.4    1.7 2020-06-29  08:25:00
# 15  13029    51.205     79.930       341.5   3.4    1.7 2020-06-29  08:25:00
# 16  13030    51.222     79.978       323.0   3.4    1.7 2020-06-29  08:25:00
# 17  13031    51.237     79.977       352.2   3.4    1.7 2020-06-29  08:25:00
# 25  17688    51.368     81.947       320.0   1.0    1.0 2020-06-29  16:15:00
# 26  17689    51.377     81.944       326.1   1.0    1.0 2020-06-29  16:15:00
# 27  17690    51.386     81.940       336.6   1.0    1.0 2020-06-29  16:15:00
# 28  17691    51.397     81.951       307.5   1.0    1.0 2020-06-29  16:15:00
# 29  17692    51.394     81.936       329.0   1.0    1.0 2020-06-29  16:15:00
# 30  17693    51.404     81.942       309.5   1.0    1.0 2020-06-29  16:15:00
# 31  17694    51.331     80.063       303.0   1.1    1.0 2020-06-29  16:15:00
# 32  17695    51.340     80.059       311.1   1.1    1.0 2020-06-29  16:15:00
# 33  18215    53.522     82.902       316.0   1.4    1.2 2020-06-29  20:20:00
# 34  18216    53.512     82.899       306.9   1.4    1.2 2020-06-29  20:20:00
# 35  18217    53.507     82.893       304.3   1.4    1.2 2020-06-29  20:20:00
# 36  18218    51.390     81.936       306.1   1.5    1.2 2020-06-29  20:20:00
# 37  18219    51.379     81.934       305.0   1.5    1.2 2020-06-29  20:20:00
# 38  29765    51.929     82.906       319.6   1.7    1.3 2020-06-26  06:10:00
# 39  30994    53.641     84.522       311.5   2.5    1.5 2020-06-26  07:55:00
# 40  34595    51.937     82.896       300.3   1.6    1.2 2020-06-26  15:45:00
# 42  43644    53.274     84.905       305.3   1.1    1.0 2020-06-30  05:45:00
# 51  48528    53.709     82.741       302.8   2.0    1.4 2020-06-28  15:30:00
#
#    SATELLITE  CONFIDENCE VERSION  BRIGHT_T31    FRP  \
# 0          A          84  6.0NRT       305.6   22.8
# 1          A          48  6.0NRT       304.7    7.8
# 2          T          31  6.0NRT       301.9   10.2
# 3          T          30  6.0NRT       294.1    7.9
# 4          A          24  6.0NRT       300.3    5.3
# 6          A          94  6.0NRT       294.9  160.1
# 7          A          80  6.0NRT       291.3   75.4
# 8          A          97  6.0NRT       298.6  366.0
# 9          A         100  6.0NRT       301.3  464.8
# 10         A          84  6.0NRT       299.6  137.9
# 11         A          69  6.0NRT       299.1   59.4
# 12         A          95  6.0NRT       299.1  323.3
# 13         A          84  6.0NRT       297.6  139.0
# 14         A          95  6.0NRT       300.0  319.0
# 15         A          91  6.0NRT       300.7  215.5
# 16         A          76  6.0NRT       299.3   79.0
# 17         A          96  6.0NRT       298.9  349.1
# 25         T          99  6.0NRT       288.9   18.7
# 26         T         100  6.0NRT       289.1   24.8
# 27         T         100  6.0NRT       290.1   38.4
# 28         T          44  6.0NRT       288.2    7.8
# 29         T         100  6.0NRT       289.9   28.0
# 30         T          78  6.0NRT       288.9   10.3
# 31         T          52  6.0NRT       286.5    7.4
# 32         T          82  6.0NRT       286.7   13.4
# 33         A          92  6.0NRT       286.8   25.9
# 34         A          70  6.0NRT       286.4   15.0
# 35         A          31  6.0NRT       285.9   11.3
# 36         A          67  6.0NRT       280.9   15.5
# 37         A          62  6.0NRT       280.2   14.4
# 38         T          57  6.0NRT       302.4   12.2
# 39         A          37  6.0NRT       296.7   18.6
# 40         T          24  6.0NRT       288.7    9.6
# 42         T          58  6.0NRT       282.0    7.2
# 51         T          51  6.0NRT       283.2   21.5
#
#                      Федеральны                  Район         Субъект
# 0   Сибирский федеральный округ       Рубцовский район  Алтайский край
# 1   Сибирский федеральный округ       Рубцовский район  Алтайский край
# 2   Сибирский федеральный округ        Зональный район  Алтайский край
# 3   Сибирский федеральный округ        Зональный район  Алтайский край
# 4   Сибирский федеральный округ     Кытмановский район  Алтайский край
# 6   Сибирский федеральный округ       Павловский район  Алтайский край
# 7   Сибирский федеральный округ       Павловский район  Алтайский край
# 8   Сибирский федеральный округ        Угловский район  Алтайский край
# 9   Сибирский федеральный округ        Угловский район  Алтайский край
# 10  Сибирский федеральный округ        Угловский район  Алтайский край
# 11  Сибирский федеральный округ        Угловский район  Алтайский край
# 12  Сибирский федеральный округ        Угловский район  Алтайский край
# 13  Сибирский федеральный округ        Угловский район  Алтайский край
# 14  Сибирский федеральный округ        Угловский район  Алтайский край
# 15  Сибирский федеральный округ        Угловский район  Алтайский край
# 16  Сибирский федеральный округ        Угловский район  Алтайский край
# 17  Сибирский федеральный округ        Угловский район  Алтайский край
# 25  Сибирский федеральный округ    Змеиногорский район  Алтайский край
# 26  Сибирский федеральный округ    Змеиногорский район  Алтайский край
# 27  Сибирский федеральный округ    Змеиногорский район  Алтайский край
# 28  Сибирский федеральный округ    Змеиногорский район  Алтайский край
# 29  Сибирский федеральный округ    Змеиногорский район  Алтайский край
# 30  Сибирский федеральный округ    Змеиногорский район  Алтайский край
# 31  Сибирский федеральный округ        Угловский район  Алтайский край
# 32  Сибирский федеральный округ        Угловский район  Алтайский край
# 33  Сибирский федеральный округ       Павловский район  Алтайский край
# 34  Сибирский федеральный округ       Павловский район  Алтайский край
# 35  Сибирский федеральный округ       Павловский район  Алтайский край
# 36  Сибирский федеральный округ    Змеиногорский район  Алтайский край
# 37  Сибирский федеральный округ    Змеиногорский район  Алтайский край
# 38  Сибирский федеральный округ  Усть-Калманский район  Алтайский край
# 39  Сибирский федеральный округ        Заринский район  Алтайский край
# 40  Сибирский федеральный округ  Усть-Калманский район  Алтайский край
# 42  Сибирский федеральный округ      Косихинский район  Алтайский край
# 51  Сибирский федеральный округ       Павловский район  Алтайский край

# %%
sum(cond_date)
# Out:
# 10281

# %%
weather_center_filename = "Погода_центры_2020.xls"
weather_center = pd.read_excel(weather_center_filename)
weather_center
# Out:
#          id         name      lon     lat  temperature  winddirection  \
# 0         1      ANADYR'  177.567  64.783           14            180
# 1         1      ANADYR'  177.567  64.783            8             10
# 2         1      ANADYR'  177.567  64.783           11             40
# 3         1      ANADYR'  177.567  64.783            8            240
# 4         1      ANADYR'  177.567  64.783            9            210
# ...     ...          ...      ...     ...          ...            ...
# 62372  1543  SEVASTOPOL'   33.533  44.617           17              0
# 62373  1544  SEVASTOPOL'   33.533  44.617           14              0
# 62374  1545  SEVASTOPOL'   33.533  44.617           13              0
# 62375  1546  SEVASTOPOL'   33.533  44.617           18            150
# 62376  1547  SEVASTOPOL'   33.533  44.617           17             90
#
#        windspeedms  precipitation  snowstorm  mist  hail  glaze_ice  blast  \
# 0                6              0          0     0     0          0      8
# 1                6          -9999          0     0     0          0     10
# 2                2              4          0     0     0          0      8
# 3                4          -9999          0     0     0          0      6
# 4                3              0          0     0     0          0      6
# ...            ...            ...        ...   ...   ...        ...    ...
# 62372            0          -9999          0     0     0          0  -9999
# 62373            0          -9999          0     0     0          0  -9999
# 62374            0          -9999          0     0     0          0  -9999
# 62375            3          -9999          0     0     0          0  -9999
# 62376            2          -9999          0     0     0          0  -9999
#
#        squall  storm_rainfall  electric_storm               datetime_d     id1
# 0           0               0               0  2020-06-22 18:00:00.000  542177
# 1           0               1               0  2020-06-23 00:00:00.000  542268
# 2           0               0               0  2020-06-23 06:00:00.000  542359
# 3           0               0               0  2020-06-23 12:00:00.000  542450
# 4           0               0               0  2020-06-23 18:00:00.000  542541
# ...       ...             ...             ...                      ...     ...
# 62372       0               0               0  2020-06-29 00:00:00.000  544537
# 62373       0               0               0  2020-06-29 00:00:00.000  544538
# 62374       0               0               0  2020-06-29 00:00:00.000  544539
# 62375       0               0               0  2020-06-29 00:00:00.000  544540
# 62376       0               0               0  2020-06-29 00:00:00.000  544541
#
# [62377 rows x 18 columns]

# %%
set(weather_center['name'])
# Out:
# {'ABAKAN',
#  "ANADYR'",
#  "ARHANGEL'SK",
#  "ASTRAHAN'",
#  'BARNAUL',
#  'BELGOROD',
#  'BIROBIDZHAN',
#  'BLAGOVESHENSK',
#  'BRYANSK',
#  'CHEBOKSARI',
#  'CHELYABINSK-GOROD',
#  'CHERKESSK',
#  'CHITA',
#  'EKATERINBURG',
#  'ELISTA',
#  'GORNAYA KARUSEL,1000',
#  'GORNAYA KARUSEL,1500',
#  'GORNO-ALTAJSK',
#  'GROZNIJ',
#  'HABAROVSK',
#  'HANTY-MANSIJSK',
#  'IMERETINKA',
#  'IRKUTSK',
#  'IVANOVO',
#  'IZHEVSK',
#  'JAKUTSK',
#  "JAROSLAVL'",
#  'JOSHKAR-OLA',
#  'JUZHNO-SAHALINSK',
#  'KALININGRAD',
#  'KALUGA',
#  "KAZAN'",
#  'KEMEROVO',
#  'KEPSHA',
#  'KIROV',
#  'KIZIL',
#  'KORDON LAURA',
#  'KOSTROMA',
#  'KRASNAYA POLYANA',
#  'KRASNODAR',
#  'KRASNOJARSK OPYTNOE POLE',
#  'KURGAN',
#  'KURSK',
#  'LIPECK',
#  'MAGADAN',
#  'MAHACKALA',
#  'MAJKOP',
#  'MOSKVA',
#  'MURMANSK',
#  "NAL'CHIK",
#  "NAR'JAN-MAR",
#  "NAZRAN'",
#  'NIZNIJ NOVGOROD',
#  'NOVGOROD',
#  'NOVOSIBIRSK',
#  'OMSK',
#  'OREL',
#  'ORENBURG',
#  'PENZA',
#  "PERM'",
#  'PETROPAVLOVSK-KAMCHATSKIJ',
#  'PETROZAVODSK',
#  'PSKOV',
#  "RJAZAN'",
#  'ROSTOV-NA-DONU',
#  'SALEHARD',
#  'SAMARA',
#  'SARANSK',
#  'SARATOV',
#  "SEVASTOPOL'",
#  "SIMFEROPOL'",
#  'SMOLENSK',
#  'SOCHI',
#  'SOLOH AUL',
#  'ST.PETERSBURG',
#  "STAVROPOL'",
#  'SYKTYVKAR',
#  'TAMBOV',
#  "TJUMEN'",
#  'TOMSK',
#  'TULA',
#  "TVER'",
#  'UFA',
#  "UL'YANOVSK",
#  'ULAN-UDE',
#  'VLADIMIR',
#  'VLADIVOSTOK',
#  'VOLGOGRAD',
#  'VOLOGDA',
#  'VORONEZ',
#  'WLADIKAVKAZ'}

# %%
set(accident_causes['Субъект РФ2'])
# Out:
# {'Автономная Республика Крым',
#  'Алтайский край',
#  'Амурская область',
#  'Архангельская область',
#  'Астраханская область',
#  'Белгородская область',
#  'Брянская область',
#  'Владимирская область',
#  'Волгоградская область',
#  'Вологодская область',
#  'Воронежская область',
#  'Еврейская автономная область',
#  'Забайкальский край',
#  'Ивановская область',
#  'Иркутская область',
#  'Кабардино-Балкарская Республика',
#  'Калининградская область',
#  'Калужская область',
#  'Карачаево-Черкесская Республика',
#  'Кемеровская область',
#  'Кировская область',
#  'Костромская область',
#  'Краснодарский край',
#  'Красноярский край',
#  'Курганская область',
#  'Курская область',
#  'Ленинградская область',
#  'Липецкая область',
#  'Московская область',
#  'Мурманская область',
#  'Нижегородская область',
#  'Новгородская область',
#  'Новосибирская область',
#  'Омская область',
#  'Оренбургская область',
#  'Орловская область',
#  'Пензенская область',
#  'Пермский край',
#  'Приморский край',
#  'Псковская область',
#  'Республика Адыгея (Адыгея)',
#  'Республика Алтай',
#  'Республика Башкортостан',
#  'Республика Бурятия',
#  'Республика Дагестан',
#  'Республика Ингушетия',
#  'Республика Калмыкия',
#  'Республика Карелия',
#  'Республика Коми',
#  'Республика Марий Эл',
#  'Республика Мордовия',
#  'Республика Саха (Якутия)',
#  'Республика Северная Осетия - Алания',
#  'Республика Татарстан (Татарстан)',
#  'Республика Тыва',
#  'Республика Хакасия',
#  'Ростовская область',
#  'Рязанская область',
#  'Самарская область',
#  'Саратовская область',
#  'Свердловская область',
#  'Смоленская область',
#  'Ставропольский край',
#  'Тамбовская область',
#  'Тверская область',
#  'Томская область',
#  'Тульская область',
#  'Тюменская область',
#  'Удмуртская Республика',
#  'Ульяновская область',
#  'Хабаровский край',
#  'Ханты-Мансийский автономный округ - Югра',
#  'Челябинская область',
#  'Чеченская Республика',
#  'Чувашская Республика - Чувашия',
#  'Ямало-Ненецкий автономный округ',
#  'Ярославская область',
#  'г. Москва',
#  'г. Санкт-Петербург'}

# %%
cities = {'ABAKAN': 'Республика Хакасия',
 "ANADYR'":"" ,
 "ARHANGEL'SK":'Архангельская область',
 "ASTRAHAN'":'Астраханская область',
 'BARNAUL':'Алтайский край',
 'BELGOROD':'Белгородская область',
 'BIROBIDZHAN':'Еврейская автономная область',
 'BLAGOVESHENSK':'Амурская область',
 'BRYANSK':'Брянская область',
 'CHEBOKSARI':'Чувашская Республика - Чувашия',
 'CHELYABINSK-GOROD':'Челябинская область',
 'CHERKESSK':'Карачаево-Черкесская Республика',
 'CHITA':'Забайкальский край',
 'EKATERINBURG':'Свердловская область',
 'ELISTA':'Республика Калмыкия',
 'GORNAYA KARUSEL,1000':"",
 'GORNAYA KARUSEL,1500':"",
 'GORNO-ALTAJSK':'Республика Алтай',
 'GROZNIJ':'Чеченская Республика',
 'HABAROVSK':'Хабаровский край',
 'HANTY-MANSIJSK':'Ханты-Мансийский автономный округ - Югра',
 'IMERETINKA':"",
 'IRKUTSK':'Иркутская область',
 'IVANOVO':'Ивановская область',
 'IZHEVSK':'Удмуртская Республика',
 'JAKUTSK':'Республика Саха (Якутия)',
 "JAROSLAVL'":'Ярославская область',
 'JOSHKAR-OLA':'Республика Марий Эл',
 'JUZHNO-SAHALINSK':"",
 'KALININGRAD':'Калининградская область',
 'KALUGA':'Калужская область',
 "KAZAN'":'Республика Татарстан (Татарстан)',
 'KEMEROVO':'Кемеровская область',
 'KEPSHA':"",
 'KIROV':'Кировская область',
 'KIZIL':'Республика Тыва',
 'KORDON LAURA':'',
 'KOSTROMA':'Костромская область',
 'KRASNAYA POLYANA':"",
 'KRASNODAR':'Краснодарский край',
 'KRASNOJARSK OPYTNOE POLE':'Красноярский край',
 'KURGAN':'Курганская область',
 'KURSK':'Курская область',
 'LIPECK':'Липецкая область',
 'MAGADAN':"",
 'MAHACKALA':'Республика Дагестан',
 'MAJKOP':'Республика Адыгея (Адыгея)',
 'MOSKVA':'г. Москва',
 'MURMANSK': 'Мурманская область',
 "NAL'CHIK":'Кабардино-Балкарская Республика',
 "NAR'JAN-MAR":"",
 "NAZRAN'":'Республика Ингушетия',
 'NIZNIJ NOVGOROD':'Нижегородская область',
 'NOVGOROD':'Новгородская область',
 'NOVOSIBIRSK':'Новосибирская область',
 'OMSK':'Омская область',
 'OREL':'Орловская область',
 'ORENBURG':'Оренбургская область',
 'PENZA':'Пензенская область',
 "PERM'":'Пермский край',
 'PETROPAVLOVSK-KAMCHATSKIJ':"",
 'PETROZAVODSK':'Республика Хакасия',
 'PSKOV':'Псковская область',
 "RJAZAN'":'Рязанская область',
 'ROSTOV-NA-DONU':'Ростовская область',
 'SALEHARD':'Ямало-Ненецкий автономный округ',
 'SAMARA':'Самарская область',
 'SARANSK':'Республика Мордовия',
 'SARATOV':'Саратовская область',
 "SEVASTOPOL'":"",
 "SIMFEROPOL'":'Автономная Республика Крым',
 'SMOLENSK':'Смоленская область',
 'ST.PETERSBURG':'Ленинградская область',
 "STAVROPOL'":'Ставропольский край',
 'SYKTYVKAR':'Республика Коми',
 'TAMBOV':'Тамбовская область',
 "TJUMEN'":'Тюменская область',
 'TOMSK':'Томская область',
 'TULA':'Тульская область',
 "TVER'":'Тверская область',
 'UFA':'Республика Башкортостан',
 "UL'YANOVSK":'Ульяновская область',
 'ULAN-UDE':'Республика Бурятия',
 'VLADIMIR':'Владимирская область',
 'VLADIVOSTOK':'Приморский край',
 'VOLGOGRAD':'Волгоградская область',
 'VOLOGDA':'Вологодская область',
 'VORONEZ':'Воронежская область',
 'WLADIKAVKAZ':'Республика Северная Осетия - Алания'}
# Out:
#   File "<ipython-input-115-424dd3082d09>", line 91
#     subjects = }
#                ^
# SyntaxError: unmatched '}'

# %%
subjects = {}
for k, v in cities.items():
    if v != "":
        subjects[v] = k

subjects['Московская область'] = 'MOSKVA'
subjects['г. Санкт-Петербург'] = 'ST.PETERSBURG'

# %%
t = accident_weather['Дата'].apply(lambda x: x.date())
accident_weather.loc[(t == datetime.date(2020, 6, 3))]
# Out:
#           Дата            Субъект РФ                       Причина  \
# 117 2020-06-03  Республика Ингушетия              Погодные явления
# 120 2020-06-03   Республика Калмыкия  Падение деревьев (природные)
# 219 2020-06-03  Чеченская Республика  Падение деревьев (природные)
# 220 2020-06-03  Чеченская Республика  Падение деревьев (природные)
# 221 2020-06-03  Чеченская Республика              Погодные явления
#
#                                            Подробности  \
# 117  3 июня в период с 18-00 до 18-30 из-за неблаго...
# 120  Причиной падения дерева являются природные при...
# 219  Причиной падения дерева являются природные при...
# 220  Причиной падения дерева являются природные при...
# 221  3 июня с 21-30 до 02-00 4 июня из-за неблагопр...
#
#                        Тип объекта
# 117  Повреждения нескольких ЛЭП\ПС
# 120                            ЛЭП
# 219                            ЛЭП
# 220                            ЛЭП
# 221  Повреждения нескольких ЛЭП\ПС

# %%
datetime.datetime.strptime(weather_center['datetime_d'][0], "%Y-%m-%d %H:%M:%S.%f")
# Out:
# datetime.datetime(2020, 6, 22, 18, 0)

# %%
weather_center['datetime_d'][0]
# Out:
# '2020-06-22 18:00:00.000'

# %%
for i in accident_weather.loc[(t == datetime.date(2020, 6, 3))].iterrows():
    print(type(i))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %%
t1 = accident_weather.loc[(t == datetime.date(2020, 6, 3))]
print(t1)
'Чеченская Республика' in t1['Субъект РФ']
# Out:
#           Дата            Субъект РФ                       Причина  \
# 117 2020-06-03  Республика Ингушетия              Погодные явления
# 120 2020-06-03   Республика Калмыкия  Падение деревьев (природные)
# 219 2020-06-03  Чеченская Республика  Падение деревьев (природные)
# 220 2020-06-03  Чеченская Республика  Падение деревьев (природные)
# 221 2020-06-03  Чеченская Республика              Погодные явления
#
#                                            Подробности  \
# 117  3 июня в период с 18-00 до 18-30 из-за неблаго...
# 120  Причиной падения дерева являются природные при...
# 219  Причиной падения дерева являются природные при...
# 220  Причиной падения дерева являются природные при...
# 221  3 июня с 21-30 до 02-00 4 июня из-за неблагопр...
#
#                        Тип объекта
# 117  Повреждения нескольких ЛЭП\ПС
# 120                            ЛЭП
# 219                            ЛЭП
# 220                            ЛЭП
# 221  Повреждения нескольких ЛЭП\ПС
# False

# %%
dictionaryRegion = {
    "RU-MOW" : "Москва",
    "RU-CHE" : "Челябинская область",
    "RU-ORL" : "Орловская область",
    "RU-OMS" : "Омская область",
    "RU-LIP" : "Липецкая область",
    "RU-KRS" : "Курская область",
    "RU-RYA" : "Рязанская область",
    "RU-BRY" : "Брянская область",
    "RU-KIR" : "Кировская область",
    "RU-ARK" : "Архангельская область",
    "RU-MUR" : "Мурманская область",
    "RU-SPE" : "Санкт-Петербург",
    "RU-YAR" : "Ярославская область",
    "RU-ULY" : "Ульяновская область",
    "RU-NVS" : "Новосибирская область",
    "RU-TYU" : "Тюменская область",
    "RU-SVE" : "Свердловская область",
    "RU-NGR" : "Новгородская область",
    "RU-KGN" : "Курганская область",
    "RU-KGD" : "Калининградская область",
    "RU-IVA" : "Ивановская область",
    "RU-AST" : "Астраханская область",
    "RU-KHA" : "Хабаровский край",
    "RU-CE" : "Чеченская республика",
    "RU-UD" : "Удмуртская республика",
    "RU-SE" : "Республика Северная Осетия",
    "RU-MO" : "Республика Мордовия",
    "RU-KR" : "Республика  Карелия",
    "RU-KL" : "Республика  Калмыкия",
    "RU-IN" : "Республика  Ингушетия",
    "RU-AL" : "Республика Алтай",
    "RU-BA" : "Республика Башкортостан",
    "RU-AD" : "Республика Адыгея",
    "RU-CR" : "Республика Крым",
    "RU-SEV" : "Севастополь",
    "RU-KO" : "Республика Коми",
    "RU-PNZ" : "Пензенская область",
    "RU-TAM" : "Тамбовская область",
    "RU-LEN" : "Ленинградская область",
    "RU-VLG" : "Вологодская область",
    "RU-KOS" : "Костромская область",
    "RU-PSK" : "Псковская область",
    "RU-YAN" : "Ямало-Ненецкий АО",
    "RU-CHU" : "Чукотский АО",
    "RU-YEV" : "Еврейская автономская область",
    "RU-TY" : "Республика Тыва",
    "RU-SAK" : "Сахалинская область",
    "RU-AMU" : "Амурская область",
    "RU-BU" : "Республика Бурятия",
    "RU-KK" : "Республика Хакасия",
    "RU-KEM" : "Кемеровская область",
    "RU-ALT" : "Алтайский край",
    "RU-DA" : "Республика Дагестан",
    "RU-KB" : "Кабардино-Балкарская республика",
    "RU-KC" : "Карачаевая-Черкесская республика",
    "RU-KDA" : "Краснодарский край",
    "RU-ROS" : "Ростовская область",
    "RU-SAM" : "Самарская область",
    "RU-TA" : "Республика Татарстан",
    "RU-ME" : "Республика Марий Эл",
    "RU-CU" : "Чувашская республика",
    "RU-NIZ" : "Нижегородская край",
    "RU-VLA" : "Владимировская область",
    "RU-MOS" : "Московская область",
    "RU-KLU" : "Калужская область",
    "RU-BEL" : "Белгородская область",
    "RU-ZAB" : "Забайкальский край",
    "RU-PRI" : "Приморский край",
    "RU-KAM" : "Камачатский край",
    "RU-MAG" : "Магаданская область",
    "RU-SA" : "Республика Саха",
    "RU-KYA" : "Красноярский край",
    "RU-ORE" : "Оренбургская область",
    "RU-SAR" : "Саратовская область",
    "RU-VGG" : "Волгоградская область",
    "RU-VOR" : "Ставропольский край",
    "RU-SMO" : "Смоленская область",
    "RU-TVE" : "Тверская область",
    "RU-PER" : "Пермская область",
    "RU-KHM" : "Ханты-Мансийский АО",
    "RU-KHM" : "Ханты-Мансийский АО",
    "RU-TOM" : "Томская область",
    "RU-IRK" : "Иркутская область",
    "RU-NEN" : "Ненецскй АО",
    "RU-STA" : "Ставропольский край",
    "RU-TUL" : "Тульская область"}

# %%
d = {}
s = []
for k, v in dictionaryRegion.items():
    d[v] = k
    s.append(v)

# %%
s.sort()
for city in s:
    print(city, d[city])
# Out:
# Алтайский край RU-ALT
# Амурская область RU-AMU
# Архангельская область RU-ARK
# Астраханская область RU-AST
# Белгородская область RU-BEL
# Брянская область RU-BRY
# Владимировская область RU-VLA
# Волгоградская область RU-VGG
# Вологодская область RU-VLG
# Еврейская автономская область RU-YEV
# Забайкальский край RU-ZAB
# Ивановская область RU-IVA
# Иркутская область RU-IRK
# Кабардино-Балкарская республика RU-KB
# Калининградская область RU-KGD
# Калужская область RU-KLU
# Камачатский край RU-KAM
# Карачаевая-Черкесская республика RU-KC
# Кемеровская область RU-KEM
# Кировская область RU-KIR
# Костромская область RU-KOS
# Краснодарский край RU-KDA
# Красноярский край RU-KYA
# Курганская область RU-KGN
# Курская область RU-KRS
# Ленинградская область RU-LEN
# Липецкая область RU-LIP
# Магаданская область RU-MAG
# Москва RU-MOW
# Московская область RU-MOS
# Мурманская область RU-MUR
# Ненецскй АО RU-NEN
# Нижегородская край RU-NIZ
# Новгородская область RU-NGR
# Новосибирская область RU-NVS
# Омская область RU-OMS
# Оренбургская область RU-ORE
# Орловская область RU-ORL
# Пензенская область RU-PNZ
# Пермская область RU-PER
# Приморский край RU-PRI
# Псковская область RU-PSK
# Республика  Ингушетия RU-IN
# Республика  Калмыкия RU-KL
# Республика  Карелия RU-KR
# Республика Адыгея RU-AD
# Республика Алтай RU-AL
# Республика Башкортостан RU-BA
# Республика Бурятия RU-BU
# Республика Дагестан RU-DA
# Республика Коми RU-KO
# Республика Крым RU-CR
# Республика Марий Эл RU-ME
# Республика Мордовия RU-MO
# Республика Саха RU-SA
# Республика Северная Осетия RU-SE
# Республика Татарстан RU-TA
# Республика Тыва RU-TY
# Республика Хакасия RU-KK
# Ростовская область RU-ROS
# Рязанская область RU-RYA
# Самарская область RU-SAM
# Санкт-Петербург RU-SPE
# Саратовская область RU-SAR
# Сахалинская область RU-SAK
# Свердловская область RU-SVE
# Севастополь RU-SEV
# Смоленская область RU-SMO
# Ставропольский край RU-STA
# Ставропольский край RU-STA
# Тамбовская область RU-TAM
# Тверская область RU-TVE
# Томская область RU-TOM
# Тульская область RU-TUL
# Тюменская область RU-TYU
# Удмуртская республика RU-UD
# Ульяновская область RU-ULY
# Хабаровский край RU-KHA
# Ханты-Мансийский АО RU-KHM
# Челябинская область RU-CHE
# Чеченская республика RU-CE
# Чувашская республика RU-CU
# Чукотский АО RU-CHU
# Ямало-Ненецкий АО RU-YAN
# Ярославская область RU-YAR
